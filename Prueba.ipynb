# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from itertools import accumulate
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error

# %%
from Paquete import PCA_mtcars, diamantes_pro, combinacion_pro, pronostico

# %% [markdown]
# # PROBLEMA 1

# %%
PCA_mtcars()
# Out:
# ANALISIS CON PCA
# BIPLOT
# CLUSTERIZACION
# C:\Users\Dekel\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Dekel\Escritorio\Prueba_tecnica\Paquete\Prueba.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   var_num['Cluster'] = clusters
#    Cluster  mpg_mean   mpg_std  disp_mean   disp_std     hp_mean     hp_std  \
# 0        0     15.10  2.560048    353.100  67.771324  209.214286  50.976886
# 1        1     27.19  4.383162    103.550  27.776899   80.000000  20.049938
# 2        2     19.95  1.467749    175.525  44.340106  120.625000  22.946755
#
#     wt_mean    wt_std  qsec_mean  qsec_std  drat_mean  drat_std
# 0  3.999214  0.759405  16.772143  1.196014   3.229286  0.372362
# 1  2.236300  0.574968  19.191000  1.763478   4.067000  0.384998
# 2  3.075000  0.350785  18.055000  1.595521   3.651250  0.478134

# %% [markdown]
# # PROBLEMA 2

# %%
diamantes_pro()
# Out:
#           cut color    pre_x_qui
# 0        Fair     D  4244.564841
# 1        Fair     E  3820.459862
# 2        Fair     F  3788.023975
# 3        Fair     G  3699.339188
# 4        Fair     H  3831.508566
# 5        Fair     I  3514.653106
# 6        Fair     J  3345.942813
# 7        Good     D  3845.999088
# 8        Good     E  3806.246564
# 9        Good     F  3820.558283
# 10       Good     G  4087.365110
# 11       Good     H  3825.520677
# 12       Good     I  3907.219571
# 13       Good     J  3524.266237
# 14      Ideal     D  3806.532106
# 15      Ideal     E  3683.171591
# 16      Ideal     F  4097.519455
# 17      Ideal     G  4163.998740
# 18      Ideal     H  3846.065529
# 19      Ideal     I  3808.070973
# 20      Ideal     J  3733.765935
# 21    Premium     D  4111.564944
# 22    Premium     E  3987.881020
# 23    Premium     F  4357.804505
# 24    Premium     G  4320.505678
# 25    Premium     H  4278.491444
# 26    Premium     I  4267.221626
# 27    Premium     J  4140.517668
# 28  Very Good     D  4072.806966
# 29  Very Good     E  3821.529542
# 30  Very Good     F  4142.189229
# 31  Very Good     G  4054.557186
# 32  Very Good     H  4034.242970
# 33  Very Good     I  4111.274074
# 34  Very Good     J  3792.497711
# ---------
# Ejemplo de elegir un precio y la probabilidad de que un diamante cueste más que ese precio
# Ejemplo 3000 da una probabilidad de:  0.43759733036707454
# Ejemplo 18000 da una probabilidad de:  0.005784204671857619

# %% [markdown]
# # PROBLEMA 3

# %%
combinacion_pro()
# Out:
# Para este inciso hice 2 funciones, una que da el al azar carro y el diamante menor al presupuesto dado por separado y otro donde los da junto
# Ejemplo, si se tiene un presupuesto  de 20000, estos son los resultados para el separada
#               mpg  cyl   disp     hp  drat    wt   qsec   vs   am  gear  carb  \
# Mejor carro  13.3  8.0  350.0  245.0  3.73  3.84  15.41  0.0  0.0   3.0   4.0
#
#                price
# Mejor carro  13300.0
#                 carat      cut color clarity  depth  table  price     x     y  \
# Mejor diamante    0.4  Premium     E     SI1   61.3   59.0    945  4.74  4.69
#
#                    z
# Mejor diamante  2.89
# --------------
# Ejemplo, si se tiene un presupuesto  de 20000, estos son los resultados para el junto, ya que la suma tiene que ser menor al presupuesto
# No hay diamentes dentro de ese presupuesto restante
#               mpg  cyl   disp     hp  drat    wt  qsec   vs   am  gear  carb  \
# Mejor carro  15.8  8.0  351.0  264.0  4.22  3.17  14.5  0.0  1.0   5.0   4.0
#
#                price
# Mejor carro  15800.0
#                 carat        cut color clarity  depth  table  price    x  \
# Mejor diamante   0.31  Very Good     H    VVS2   61.9   58.0    625  4.3
#
#                    y     z
# Mejor diamante  4.33  2.67
# -------------
# Para el último inciso se optimizó para aprovechar todo el presupuesto, en este caso se utilizó también 20000
#         mpg  cyl   disp     hp  drat    wt   qsec   vs   am  gear  carb  \
# Carro  18.7  8.0  360.0  175.0  3.15  3.44  17.02  0.0  0.0   3.0   2.0
#
#          price
# Carro  18700.0
#           carat      cut color clarity  depth  table  price     x     y     z
# Diamante   0.39  Premium     E    VVS1   60.7   58.0   1300  4.69  4.73  2.86

# %% [markdown]
# # PROBLEMA 4

# %%
pronostico()
# Out:
# --------------
# Hacemos pruebas estadísticas para ver si es estacionaria
# Estadístico ADF: -5.1224102133399265
# p-value: 1.2635033913494854e-05
# p-value después de la diferencia: 0.0011498464874649102
# --------------
# Se divide los datos en train y test para poder lograr un buen modelo con ARIMA y se grafica
# C:\Users\Dekel\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\Dekel\AppData\Local\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Dekel\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\Dekel\AppData\Local\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\Dekel\AppData\Local\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Dekel\AppData\Local\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Errores: [11.187651295431003, 11.353810059198508, 6.088781457379275, 3.795048046262617]
# STD_RMSE: 3.2671976473274795
# --------------
# Por último se toma el mejor modelo que se entrenó y se aplica para predecir los siguiente 6 meses
# C:\Users\Dekel\AppData\Local\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
